# %%
# Importing Libraries/Dependencies
import pandas as pd
import numpy as np
import time
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver 
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.chrome.service import Service
import requests
import re
import warnings
warnings.filterwarnings("ignore")

# %%
# Connecting to the webdriver
driver = webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %% [markdown]
# AHMEDABAD

# %%
url = "https://www.cardekho.com/used-cars+in+ahmedabad"
driver.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
manuf_year=[]
Driven_KM=[]
fuel=[]
location=[]
No_owners=[]
price=[]

# %%
time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver.find_elements_by_xpath("//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements_by_xpath("//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver.find_elements_by_xpath("//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df1=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df1
# Out:
#                          Brand       Price                Model    KMS_driven  \
# 0              2018 Honda Jazz   7.05 Lakh                V CVT    64,554 kms
# 1           2018 Hyundai Verna  10.00 Lakh   VTVT 1.6 SX Option    54,195 kms
# 2         2018 Maruti Alto 800   3.50 Lakh                  LXI     5,709 kms
# 3              2016 Honda Jazz   6.25 Lakh                V CVT    39,821 kms
# 4             2018 Hyundai i20   6.37 Lakh            1.2 Spotz    29,771 kms
# ..                         ...         ...                  ...           ...
# 715         2016 Hyundai Creta   9.95 Lakh  1.6 VTVT AT SX Plus    42,000 kms
# 716        2004 Maruti Wagon R       50000                   LX  1,10,000 kms
# 717            2003 Maruti 800       45000                   AC  1,00,000 kms
# 718  2017 Toyota Innova Crysta  16.90 Lakh      2.4 VX MT 8 STR    70,000 kms
# 719       2018 Maruti Alto 800   3.60 Lakh                  LXI    65,000 kms
#
#        Fuel    Variant
# ...

# %%
driver.close()

# %% [markdown]
# BANGALORE

# %%
# Connecting to the webdriver
driver = webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+bangalore"
driver.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver.find_elements_by_xpath("//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements_by_xpath("//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver.find_elements_by_xpath("//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df2=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df2
# Out:
#                    Brand       Price                        Model  KMS_driven  \
# 0    2014 Maruti Wagon R   4.30 Lakh                    VXI BS IV  20,844 kms
# 1        2020 Maruti XL6  11.70 Lakh                     Alpha AT  10,193 kms
# 2   2017 Toyota Fortuner  28.41 Lakh              2.8 2WD MT BSIV  48,836 kms
# 3        2018 Tata Nexon   7.92 Lakh                         KRAZ  15,176 kms
# 4         2020 MG Hector  19.90 Lakh                    Sharp DCT  13,165 kms
# ..                   ...         ...                          ...         ...
# 75      2017 Ford Aspire   5.85 Lakh          1.2 Ti-VCT Titanium  52,000 kms
# 76    2016 Ford Ecosport   7.45 Lakh  1.5 Ti VCT MT Titanium BSIV  65,000 kms
# 77    2018 Skoda Octavia  34.75 Lakh                        RS245  10,000 kms
# 78    2016 Hyundai Creta   8.35 Lakh                   1.6 VTVT S  74,085 kms
# 79  2012 Mahindra XUV500   7.15 Lakh                       W8 FWD  57,000 kms
#
#       Fuel    Variant
# ...

# %%
frames = [df1, df2]
  
result = pd.concat(frames)
display(result)
# Out:
#                    Brand       Price                        Model  KMS_driven  \
# 0        2018 Honda Jazz   7.05 Lakh                        V CVT  64,554 kms
# 1     2018 Hyundai Verna  10.00 Lakh           VTVT 1.6 SX Option  54,195 kms
# 2   2018 Maruti Alto 800   3.50 Lakh                          LXI   5,709 kms
# 3        2016 Honda Jazz   6.25 Lakh                        V CVT  39,821 kms
# 4       2018 Hyundai i20   6.37 Lakh                    1.2 Spotz  29,771 kms
# ..                   ...         ...                          ...         ...
# 75      2017 Ford Aspire   5.85 Lakh          1.2 Ti-VCT Titanium  52,000 kms
# 76    2016 Ford Ecosport   7.45 Lakh  1.5 Ti VCT MT Titanium BSIV  65,000 kms
# 77    2018 Skoda Octavia  34.75 Lakh                        RS245  10,000 kms
# 78    2016 Hyundai Creta   8.35 Lakh                   1.6 VTVT S  74,085 kms
# 79  2012 Mahindra XUV500   7.15 Lakh                       W8 FWD  57,000 kms
#
#       Fuel    Variant
# ...

# %% [markdown]
# MUMBAI

# %%
# Connecting to the webdriver
driver1 = webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+mumbai"
driver1.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver1.find_elements_by_xpath("//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver1.find_elements_by_xpath("//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver1.find_elements_by_xpath("//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver1.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver1.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver1.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df3=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df3
# Out:
#                          Brand       Price                       Model  \
# 0           2018 Hyundai Creta  10.94 Lakh  1.6 VTVT SX Plus Dual Tone
# 1             2015 Skoda Rapid   4.74 Lakh              1.5 TDI Active
# 2        2018 Mahindra TUV 300   7.90 Lakh                         T10
# 3           2019 Hyundai Venue  10.50 Lakh      SX Plus Turbo DCT BSIV
# 4            2013 Maruti Swift   3.40 Lakh                         VXI
# ..                         ...         ...                         ...
# 395           2016 Maruti Ciaz   6.11 Lakh                         ZXi
# 396         2016 Hyundai Creta   9.90 Lakh                 1.6 CRDi SX
# 397         2016 Hyundai Xcent   4.65 Lakh                1.2 Kappa SX
# 398          2014 Maruti Swift   4.20 Lakh                     VVT VXI
# 399  2018 Maruti Vitara Brezza   8.72 Lakh                         ZDi
#
#      KMS_driven    Fuel    Variant
# 0    63,947 kms  Petrol     Manual
# 1    63,855 kms  Diesel     Manual
# ...

# %%
frame = [result, df3]
  
r1 = pd.concat(frame)
display(r1)
# Out:
#                          Brand       Price               Model  KMS_driven  \
# 0              2018 Honda Jazz   7.05 Lakh               V CVT  64,554 kms
# 1           2018 Hyundai Verna  10.00 Lakh  VTVT 1.6 SX Option  54,195 kms
# 2         2018 Maruti Alto 800   3.50 Lakh                 LXI   5,709 kms
# 3              2016 Honda Jazz   6.25 Lakh               V CVT  39,821 kms
# 4             2018 Hyundai i20   6.37 Lakh           1.2 Spotz  29,771 kms
# ..                         ...         ...                 ...         ...
# 395           2016 Maruti Ciaz   6.11 Lakh                 ZXi  80,117 kms
# 396         2016 Hyundai Creta   9.90 Lakh         1.6 CRDi SX  89,626 kms
# 397         2016 Hyundai Xcent   4.65 Lakh        1.2 Kappa SX  16,893 kms
# 398          2014 Maruti Swift   4.20 Lakh             VVT VXI  43,268 kms
# 399  2018 Maruti Vitara Brezza   8.72 Lakh                 ZDi  66,046 kms
#
#        Fuel    Variant
# 0    Petrol  Automatic
# ...

# %%
driver1.close()

# %% [markdown]
# JAIPUR

# %%
# Connecting to the webdriver
driver2 = webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+jaipur"
driver2.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver2.find_elements_by_xpath("//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver2.find_elements_by_xpath("//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver2.find_elements_by_xpath("//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver2.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver2.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver2.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df4=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df4
# Out:
#                          Brand       Price           Model  KMS_driven  \
# 0           2021 Maruti Baleno   7.85 Lakh           Delta  16,477 kms
# 1              2020 Honda City  12.66 Lakh          ZX CVT  36,404 kms
# 2    2018 Maruti Vitara Brezza   8.10 Lakh             ZDi  90,324 kms
# 3            2014 BMW 3 Series  15.76 Lakh   320d Prestige  90,649 kms
# 4       2015 Toyota Etios Liva   6.11 Lakh              GD  58,191 kms
# ..                         ...         ...             ...         ...
# 555     2018 Hyundai Grand i10   4.96 Lakh  1.2 CRDi Magna  83,216 kms
# 556     2016 Hyundai Grand i10   4.50 Lakh     CRDi Sportz  96,727 kms
# 557            2014 Honda City   6.76 Lakh        i DTEC V  65,931 kms
# 558        2018 Maruti Wagon R   4.42 Lakh       VXI BS IV  58,712 kms
# 559          2015 Maruti Swift   5.43 Lakh             VXI  51,218 kms
#
#        Fuel    Variant
# 0    Petrol     Manual
# 1    Petrol  Automatic
# 2    Diesel     Manual
# ...

# %%
fram = [r1, df4]
  
r2 = pd.concat(fram)
display(r2)
# Out:
#                       Brand       Price               Model  KMS_driven  \
# 0           2018 Honda Jazz   7.05 Lakh               V CVT  64,554 kms
# 1        2018 Hyundai Verna  10.00 Lakh  VTVT 1.6 SX Option  54,195 kms
# 2      2018 Maruti Alto 800   3.50 Lakh                 LXI   5,709 kms
# 3           2016 Honda Jazz   6.25 Lakh               V CVT  39,821 kms
# 4          2018 Hyundai i20   6.37 Lakh           1.2 Spotz  29,771 kms
# ..                      ...         ...                 ...         ...
# 555  2018 Hyundai Grand i10   4.96 Lakh      1.2 CRDi Magna  83,216 kms
# 556  2016 Hyundai Grand i10   4.50 Lakh         CRDi Sportz  96,727 kms
# 557         2014 Honda City   6.76 Lakh            i DTEC V  65,931 kms
# 558     2018 Maruti Wagon R   4.42 Lakh           VXI BS IV  58,712 kms
# 559       2015 Maruti Swift   5.43 Lakh                 VXI  51,218 kms
#
#        Fuel    Variant
# 0    Petrol  Automatic
# 1    Petrol     Manual
# 2    Petrol     Manual
# ...

# %%
driver2.close()

# %% [markdown]
# GURGAON

# %%
# Connecting to the webdriver
driver3 = webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+gurgaon"
driver3.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver3.find_elements_by_xpath("//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver3.find_elements_by_xpath("//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver3.find_elements_by_xpath("//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver3.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver3.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver3.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df5=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df5
# Out:
#                        Brand       Price                     Model  \
# 0          2017 Maruti Swift   4.65 Lakh            LXI Optional-O
# 1         2017 Hyundai Creta   9.85 Lakh       1.6 VTVT AT SX Plus
# 2    2014 Toyota Etios Cross   3.47 Lakh                   1.4L VD
# 3         2017 Ford Ecosport   6.78 Lakh  1.5 Diesel Ambiente BSIV
# 4       2015 Mahindra XUV500   8.59 Lakh                   W10 AWD
# ..                       ...         ...                       ...
# 555     2018 Maruti Alto 800   3.35 Lakh                       LXI
# 556   2016 Hyundai Grand i10   3.58 Lakh               CRDi Sportz
# 557      2018 Renault Captur   7.45 Lakh            1.5 Petrol RXL
# 558    2020 Mahindra Scorpio  16.90 Lakh                       S11
# 559       2021 Renault Kiger   8.02 Lakh                   RXT AMT
#
#      KMS_driven    Fuel    Variant
# 0    24,422 kms  Petrol     Manual
# 1    62,871 kms  Petrol  Automatic
# 2    92,010 kms  Diesel     Manual
# ...

# %%
fra = [r2, df5]
  
r3 = pd.concat(fra)
display(r3)
# Out:
#                       Brand       Price               Model  KMS_driven  \
# 0           2018 Honda Jazz   7.05 Lakh               V CVT  64,554 kms
# 1        2018 Hyundai Verna  10.00 Lakh  VTVT 1.6 SX Option  54,195 kms
# 2      2018 Maruti Alto 800   3.50 Lakh                 LXI   5,709 kms
# 3           2016 Honda Jazz   6.25 Lakh               V CVT  39,821 kms
# 4          2018 Hyundai i20   6.37 Lakh           1.2 Spotz  29,771 kms
# ..                      ...         ...                 ...         ...
# 555    2018 Maruti Alto 800   3.35 Lakh                 LXI  25,508 kms
# 556  2016 Hyundai Grand i10   3.58 Lakh         CRDi Sportz  64,318 kms
# 557     2018 Renault Captur   7.45 Lakh      1.5 Petrol RXL  15,245 kms
# 558   2020 Mahindra Scorpio  16.90 Lakh                 S11  31,462 kms
# 559      2021 Renault Kiger   8.02 Lakh             RXT AMT   5,799 kms
#
#        Fuel    Variant
# 0    Petrol  Automatic
# 1    Petrol     Manual
# 2    Petrol     Manual
# ...

# %%
driver3.close()

# %% [markdown]
# DELHI NCR

# %%
# Connecting to the webdriver
driver4 = webdriver.Chrome(r"C:\Users\user\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+delhi-ncr"
driver4.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver4.find_elements_by_xpath("//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver4.find_elements_by_xpath("//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver4.find_elements_by_xpath("//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver4.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver4.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver4.find_elements_by_xpath(("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df6=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df6
# Out:
#                        Brand       Price                     Model  \
# 0          2017 Maruti Swift   4.65 Lakh            LXI Optional-O
# 1         2017 Hyundai Creta   9.85 Lakh       1.6 VTVT AT SX Plus
# 2    2014 Toyota Etios Cross   3.47 Lakh                   1.4L VD
# 3         2017 Ford Ecosport   6.78 Lakh  1.5 Diesel Ambiente BSIV
# 4       2015 Mahindra XUV500   8.59 Lakh                   W10 AWD
# ..                       ...         ...                       ...
# 555     2014 Maruti Alto K10   2.90 Lakh                       VXI
# 556     2015 Mahindra XUV500   8.59 Lakh                   W10 AWD
# 557           2019 MG Hector  16.61 Lakh                 Sharp DCT
# 558      2018 Renault Captur   7.45 Lakh            1.5 Petrol RXL
# 559       2019 Hyundai Venue  10.72 Lakh    SX Plus Turbo DCT BSIV
#
#      KMS_driven    Fuel    Variant
# 0    24,422 kms  Petrol     Manual
# 1    62,871 kms  Petrol  Automatic
# 2    92,010 kms  Diesel     Manual
# ...

# %%
fr = [r3, df6]
  
r4 = pd.concat(fr)
display(r4)
# Out:
#                     Brand       Price                   Model  KMS_driven  \
# 0         2018 Honda Jazz   7.05 Lakh                   V CVT  64,554 kms
# 1      2018 Hyundai Verna  10.00 Lakh      VTVT 1.6 SX Option  54,195 kms
# 2    2018 Maruti Alto 800   3.50 Lakh                     LXI   5,709 kms
# 3         2016 Honda Jazz   6.25 Lakh                   V CVT  39,821 kms
# 4        2018 Hyundai i20   6.37 Lakh               1.2 Spotz  29,771 kms
# ..                    ...         ...                     ...         ...
# 555  2014 Maruti Alto K10   2.90 Lakh                     VXI  21,191 kms
# 556  2015 Mahindra XUV500   8.59 Lakh                 W10 AWD  47,454 kms
# 557        2019 MG Hector  16.61 Lakh               Sharp DCT  34,880 kms
# 558   2018 Renault Captur   7.45 Lakh          1.5 Petrol RXL  15,245 kms
# 559    2019 Hyundai Venue  10.72 Lakh  SX Plus Turbo DCT BSIV  11,532 kms
#
#        Fuel    Variant
# 0    Petrol  Automatic
# 1    Petrol     Manual
# ...

# %%
driver4.close()

# %%
# Saving the scraped data into excel file
r4.to_excel("Used_Cars_Data.xlsx")

# %%
# Saving the scraped data into csv file
r4.to_csv("Used_Cars_Data.csv")
